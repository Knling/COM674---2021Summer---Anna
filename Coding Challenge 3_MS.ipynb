# %% [markdown]
# ## Chapter 5

# %% [markdown]
# ### Exercise 1: Write a program which repeatedly reads numbers until the user enters “done”. Once “done” is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.

# %%
count=0
total=0
average=0
while True:
     number = input("Enter a number: ")
     if number == "done":
        break
     try: 
        num=int(number)
     except:
        print("Invalid input")
        continue
     total=total+num
     count=count+1
     average=total/count
print(total,count,average)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

# %% [markdown]
# ### Exercise 2: Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.

# %%
count=0
total=0
largest=None
smallest=None
while True:
     number = input("Enter a number: ")
     if number == "done":
        break
     try: 
        num=int(number)
     except:
        print("Invalid input")
        continue
     total=total+num
     count=count+1
     if largest is None or num > largest:
        largest = num
     if smallest is None or num < smallest:
        smallest = num
print(total,count,largest,smallest)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: 16
# Enter a number: 1
# Enter a number: done
# 33 5 16 1

# %% [markdown]
# ## Chapter 6

# %% [markdown]
# ### Exercise 5: Take the following Python code that stores a string:
#  * str = 'X-DSPAM-Confidence:0.8475'
# ### Use find and string slicing to extract the portion of the string after the colon character and then use the float function to convert the extracted string into a floating point number.

# %%
data = 'X-DSPAM-Confidence:0.8475'
index = data.find(':')
number=float(data[index+1:])
print(number)
# Out:
# 0.8475

# %% [markdown]
# ## Chapter 8

# %% [markdown]
# ### Exercise 6: Rewrite the program that prompts the user for a list of numbers and prints out the maximum and minimum of the numbers at the end when the user enters “done”. Write the program to store the numbers the user enters in a list and use the max() and min() functions to compute the maximum and minimum numbers after the loop completes.

# %%
numlist=list()
maxnum=None
minnum=None
while (True):
    number = input('Enter a number: ')
    if number == 'done': 
        break
    try: 
        num=int(number)
    except:
        print("Invalid input")
        continue
    num = float(number)
    numlist.append(num)
    maxnum=max(numlist)
    minnum=min(numlist)
print("Maximum:"+str(maxnum))
print("Minimum:"+str(minnum))
# Out:
# Enter a number: 6
# Enter a number: 2
# Enter a number: 9
# Enter a number: 3
# Enter a number: 5
# Enter a number: done
# Maximum:9.0
# Minimum:2.0

# %% [markdown]
# ## Wordplay Challenges

# %% [markdown]
# ### Question 1: Find all words that start with 'a' and are 9 or more letters long.

# %%
import scrabble

# %%
for word in scrabble.wordlist:
    if word.startswith('a') and len(word) >= 9:
        print(word)
# Out:
# aardvarks
# aardwolves
# aasvogels
# abacterial
# abactinal
# abactinally
# abamperes
# abandoned
# abandonedly
# abandonee
# abandonees
# abandoner
# abandoners
# abandoning
# abandonment
# abandonments
# abandonware
# abandonwares
# abasement
# abasements
# abashedly
# abashless
# abashment
# abashments
# abatement
# abatements
# abattises
# abattoirs
# abbotcies
# abbotship
# abbotships
# abbreviate
# abbreviated
# abbreviates
# abbreviating
# abbreviation
# abbreviations
# abbreviator
# abbreviators
# abbreviatory
# abbreviature
# abbreviatures
# abcoulomb
# abcoulombs
# abdicable
# abdicated
# abdicates
# abdicating
# abdication
# abdications
# abdicative
# abdicator
# abdicators
# abdominal
# abdominally
# abdominals
# abdominoplasty
# abdominous
# abducentes
# abductees
# abducting
# abduction
# abductions
# abductores
# abductors
# abecedarian
# abecedarians
# abelmosks
# aberdevine
# aberdevines
# abernethies
# abernethy
# aberrance
# aberrances
# aberrancies
# aberrancy
# ...

# %% [markdown]
# ### Question 2: What is the longest word that starts with a 'q'?

# %%
curr_word = ''
curr_length = 0
max_words = list()
max_length = 0
for word in scrabble.wordlist:
    if word.startswith('q'):
        curr_word = word
        curr_length = len(curr_word)
        if max_length == 0 or curr_length > max_length:
            max_length = len(curr_word)
            max_words = [curr_word]
        elif curr_length == max_length:
            max_words.append(curr_word)
print(max_words)
# Out:
# ['quadragenarians', 'quadringenaries', 'quadripartition', 'quadrisyllables', 'quadrivalencies', 'quadruplicating', 'quadruplication', 'quadruplicities', 'quantifications', 'quarrelsomeness', 'quarterfinalist', 'quartermistress', 'quatercentenary', 'quattrocentisms', 'quattrocentists', 'querulousnesses', 'questionability', 'quicksilverings', 'quincentenaries', 'quincentennials', 'quingentenaries', 'quinquagenarian', 'quinquevalences', 'quintuplicating', 'quintuplication', 'quizzifications', 'quodlibetarians', 'quodlibetically']

# %% [markdown]
# ### Question 3: Find all words that end with 'nge'

# %%
for word in scrabble.wordlist:
    if word.endswith('nge'):
        print(word)
# Out:
# accinge
# allonge
# arrange
# astringe
# avenge
# befringe
# binge
# blancmange
# blunge
# breenge
# breinge
# challenge
# change
# chaunge
# citrange
# conge
# constringe
# counterchange
# cringe
# derange
# dinge
# disarrange
# disponge
# dispunge
# downrange
# emplonge
# emunge
# enrange
# enraunge
# enterchaunge
# estrange
# exchange
# expunge
# flange
# fontange
# fringe
# gearchange
# ginge
# grange
# grunge
# gunge
# henge
# hinge
# impinge
# implunge
# infringe
# interchange
# kitenge
# longe
# lounge
# lozenge
# lunge
# mange
# mangemange
# maskallonge
# maskalonge
# maskanonge
# maskinonge
# melange
# menge
# midrange
# minge
# misarrange
# mischallenge
# multirange
# muskellunge
# omnirange
# orange
# outrange
# overarrange
# peenge
# perstringe
# phalange
# plonge
# plunge
# prearrange
# prolonge
# range
# raunge
# rearrange
# rechallenge
# rechange
# refringe
# rehinge
# replunge
# restringe
# revenge
# scavenge
# scrounge
# scunge
# shortchange
# singe
# sponge
# ...

# %% [markdown]
# ### Question 4: Find a word that matches "a * ey" (here "*" means any letter). Are there any words that match?

# %%
for letter in "abcdefghijklmnopqrstuvwxyz":
    exists = False
    for word in scrabble.wordlist:
        if 'a'+letter+'ey' in word:
            exists = True
            break
    if exists: break
if exists:
    print("A word that matches 'a*ey' exists! It is "+word)
if not exists:
    print("A word that matches 'a*ey' does not exist!")
      
for letter in "abcdefghijklmnopqrstuvwxyz":
    exists = False
    for word in scrabble.wordlist:
        if 'a'+letter+'ey' in word:
            exists = True
            print(word)

for letter in "abcdefghijklmnopqrstuvwxyz":
    for word in scrabble.wordlist:
        if 'a'+letter+'ey' in word:
            print(word)
# Out:
# A word that matches 'a*ey' exists! It is abeyance

# %%
for word in scrabble.wordlist:
    start=word.find('a')
    if word[start+2:start+4] == 'ey':
        print(word)
# Out:
# abeyance
# abeyances
# abeyancies
# abeyancy
# abeyant
# aleye
# aleyed
# aleyes
# aleying

# %% [markdown]
# ### Question 5: Print every other word that matches the condition in (1) above.

# %%
count=1
for word in scrabble.wordlist:
    if word.startswith('a') and len(word) >= 9:
        count=count+1
        if count%2 == 0:
            print(word)
# Out:
# aardvarks
# aasvogels
# abactinal
# abamperes
# abandonedly
# abandonees
# abandoners
# abandonment
# abandonware
# abasement
# abashedly
# abashment
# abatement
# abattises
# abbotcies
# abbotships
# abbreviated
# abbreviating
# abbreviations
# abbreviators
# abbreviature
# abcoulomb
# abdicable
# abdicates
# abdication
# abdicative
# abdicators
# abdominally
# abdominoplasty
# abducentes
# abducting
# abductions
# abductors
# abecedarians
# aberdevine
# abernethies
# aberrance
# aberrancies
# aberrantly
# aberrated
# aberrating
# aberrational
# abessives
# abeyances
# abhenries
# abhorrence
# abhorrencies
# abhorrent
# abhorrers
# abhorrings
# abidingly
# abiogeneses
# abiogenetic
# abiogenic
# abiogenist
# abiological
# abiotrophic
# abiotrophy
# abirritants
# abirritated
# abirritating
# abiturients
# abjection
# abjectness
# abjointed
# abjunction
# abjuration
# ablactation
# ablations
# ablatival
# ablatives
# ablutionary
# ablutomane
# abnegated
# abnegating
# abnegations
# ...

# %% [markdown]
# ### Question 6: Find at least one word that uses all five vowels in order.

# %%
VOWELS = ['a', 'e', 'i', 'o', 'u']
for word in scrabble.wordlist:
    all_vowels = True
    for vowel in VOWELS:
        if vowel not in word:
            all_vowels = False
    if all_vowels == True:
        index=0
        count=0
        for vowel in VOWELS:
            if index==0 or word.find(vowel) > index:
                index = word.find(vowel)
                count=count+1
        if count == 5:    
            print(word + " has all five vowels in order")
# Out:
# abstemious has all five vowels in order
# abstemiously has all five vowels in order
# abstemiousness has all five vowels in order
# abstentious has all five vowels in order
# adventitious has all five vowels in order
# adventitiously has all five vowels in order
# amentiferous has all five vowels in order
# antenniferous has all five vowels in order
# arenicolous has all five vowels in order
# argentiferous has all five vowels in order
# arsenious has all five vowels in order
# arteriovenous has all five vowels in order
# asclepiadaceous has all five vowels in order
# bacteriophagous has all five vowels in order
# caesious has all five vowels in order
# cavernicolous has all five vowels in order
# chaetiferous has all five vowels in order
# facetious has all five vowels in order
# facetiously has all five vowels in order
# facetiousness has all five vowels in order
# facetiousnesses has all five vowels in order
# flagelliferous has all five vowels in order
# ...

# %%
vowels =['a','e','i','o','u']
for word in scrabble.wordlist:
    curr_vowel = 0
    for letter in word:
        if letter==vowels[curr_vowel]:
            curr_vowel=curr_vowel+1
            if curr_vowel==len(vowels):
                print(word)
                break
# Out:
# abstemious
# abstemiously
# abstemiousness
# abstentious
# adventitious
# adventitiously
# aeruginous
# amentiferous
# androdioecious
# andromonoecious
# anemophilous
# antenniferous
# antireligious
# arenicolous
# argentiferous
# arsenious
# arteriovenous
# asclepiadaceous
# autecious
# autoecious
# autoeciously
# bacteriophagous
# caesious
# cavernicolous
# chaetiferous
# facetious
# facetiously
# facetiousness
# facetiousnesses
# facinerious
# flagelliferous
# garnetiferous
# halfseriously
# hamamelidaceous
# lateritious
# parecious
# paroecious
# quadrigeminous
# sacrilegious
# sacrilegiously
# sarraceniaceous
# ultraserious
# valerianaceous
